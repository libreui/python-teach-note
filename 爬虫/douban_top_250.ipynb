# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/88.0.4324.104 Safari/537.36',
    'Cookie': 'bid=2OXOUlk8z6A; douban-fav-remind=1; __utmz=30149280.1721792513.1.1.utmcsr=baidu|utmccn=(organic)|utmcmd=organic; ap_v=0,6.0; _pk_id.100001.4cf6=8c535ae428a78eef.1730956884.; __utmc=30149280; __utmc=223695111; ll="118145"; __utma=30149280.351232312.1721792513.1730956885.1730960292.3; __utmt=1; __utmb=30149280.1.10.1730960292; dbcl2="132982081:Ja5zRpRRWzE"; ck=1htc; __utma=223695111.1707810684.1730956885.1730956885.1730960347.2; __utmb=223695111.0.10.1730960347; __utmz=223695111.1730960347.2.2.utmcsr=accounts.douban.com|utmccn=(referral)|utmcmd=referral|utmcct=/; _pk_ref.100001.4cf6=%5B%22%22%2C%22%22%2C1730960347%2C%22https%3A%2F%2Faccounts.douban.com%2F%22%5D; _pk_ses.100001.4cf6=1; push_noty_num=0; push_doumail_num=0; _vwo_uuid_v2=D25DFC4414F621F18B9C36B6A2C3BE2D1|22c0a2e0fe011d78aa6bd1820d575ecc; frodotk_db="821d2d5a15ee074f8657880e41ca15ed"'
}

# %%
def html_download():
    html_text = []
    for page in range(0, 226, 25):
        time.sleep(1)
        url = 'https://movie.douban.com/top250?start=' + str(page) + '&filter='
        print(f"正在爬取{url}")
        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            raise Exception(f"请求失败: {response.status_code} {url}")
        html_text.append(response.text)
        
    print("内容长度", len(html_text))
    return html_text

# %%
htmls = html_download()
# Out:
# 正在爬取https://movie.douban.com/top250?start=0&filter=
# 正在爬取https://movie.douban.com/top250?start=25&filter=
# 正在爬取https://movie.douban.com/top250?start=50&filter=
# 正在爬取https://movie.douban.com/top250?start=75&filter=
# 正在爬取https://movie.douban.com/top250?start=100&filter=
# 正在爬取https://movie.douban.com/top250?start=125&filter=
# 正在爬取https://movie.douban.com/top250?start=150&filter=
# 正在爬取https://movie.douban.com/top250?start=175&filter=
# 正在爬取https://movie.douban.com/top250?start=200&filter=
# 正在爬取https://movie.douban.com/top250?start=225&filter=
# 内容长度 10

# %%
data = []
for html in htmls:
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.find_all("div", class_="item")
    for item in items:
        try:
            row = {
                "rank": item.find("em").text,
                "title": item.find("span", class_="title").text,
                "score": item.find("span", class_="rating_num").text,
                "comments": item.find("div", class_="star").find_all("span")[-1].text.replace("人评价", ""),
                "quote": item.find("span", class_="inq").text
            }
            data.append(row)
        except AttributeError:
            pass

# %%
from pprint import pprint
pprint(data)
# Out:
# [{'comments': '3081722',
#   'quote': '希望让人自由。',
#   'rank': '1',
#   'score': '9.7',
#   'title': '肖申克的救赎'},
#  {'comments': '2275027',
#   'quote': '风华绝代。',
#   'rank': '2',
#   'score': '9.6',
#   'title': '霸王别姬'},
#  {'comments': '2294331',
#   'quote': '一部美国近现代史。',
#   'rank': '3',
#   'score': '9.5',
#   'title': '阿甘正传'},
#  {'comments': '2334683',
#   'quote': '失去的才是永恒的。 ',
#   'rank': '4',
#   'score': '9.5',
#   'title': '泰坦尼克号'},
#  {'comments': '2383143',
#   'quote': '最好的宫崎骏，最好的久石让。 ',
#   'rank': '5',
#   'score': '9.4',
#   'title': '千与千寻'},
#  {'comments': '1402384',
#   'quote': '最美的谎言。',
#   'rank': '6',
#   'score': '9.5',
#   'title': '美丽人生'},
#  {'comments': '2425987',
#   'quote': '怪蜀黍和小萝莉不得不说的故事。',
#   'rank': '7',
#   'score': '9.4',
#   'title': '这个杀手不太冷'},
#  {'comments': '2006337',
#   'quote': '爱是一种力量，让我们超越时空感知它的存在。',
#   'rank': '8',
#   'score': '9.4',
#   'title': '星际穿越'},
#  {'comments': '2194580',
#   'quote': '诺兰给了我们一场无法盗取的梦。',
#   'rank': '9',
# ...

# %%
import pandas
df = pandas.DataFrame(data)

# %%
df
# Out:
#     rank   title score                                        quote
# 0      1  肖申克的救赎   9.7                                      希望让人自由。
# 1      2    霸王别姬   9.6                                        风华绝代。
# 2      3    阿甘正传   9.5                                    一部美国近现代史。
# 3      4   泰坦尼克号   9.5                                   失去的才是永恒的。
# 4      5    千与千寻   9.4                              最好的宫崎骏，最好的久石让。
# ..   ...     ...   ...                                          ...
# 223  243    魂断蓝桥   8.8                                  中国式内在的美国电影。
# 224  246      弱点   8.7                       拍掉身上的悲伤，从今天开始重新踏上追梦之旅。
# 225  247    谍影重重   8.6                  哗啦啦啦啦，天在下雨，哗啦啦啦啦，云在哭泣……找自己。
# 226  249     朗读者   8.6  当爱情跨越年龄的界限，它似乎能变得更久远一点，成为一种责任，一种水到渠成的相濡以沫。
# 227  250    阿飞正传   8.5                           王家卫是一种风格，张国荣是一个代表。
#
# [228 rows x 4 columns]

# %%
df.to_excel("./data/douban_top_250.xlsx", index=False)
