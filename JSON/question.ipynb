# %%
import json

from numpy import dtype
from numpy.matrixlib.defmatrix import matrix
from numpy.testing.print_coercion_tables import print_new_cast_table
from pandas import Series

# 问题1：
# 1. 解析这个books.json
# 2. 把其中数的一些字段整理出来，比如：书名、作者、出版社、出版日期、价格、
# 3. 使用表格库tabulate打印出来
# 4. 保存表格到json文件
json.dump(books, f, ensure_ascii=False, indent=4)

# %%
import numpy as np

arr_a = np.array([[1, 2], [4, 5]])
print(arr_a)
# arr_b = np.reshape(arr_a, (4, 3))
# print(arr_b)
arr_c = np.reshape(arr_a, (6, 3))
print(arr_c)

# %%
import pandas as pd
import numpy as np

# arr = [
#     ['张三', 18, '男'],
#     ['李四', 19, '男'],
#     ['王五', 20, '男'],
#     ['赵六', 21, '男'],
# ]
# df = pd.DataFrame(arr, columns=['姓名', '年龄', '性别'])
# print(df)

# arr = {
#     '姓名': ['张三', '李四', '王五', '赵六'],
#     '年龄': [18, 19, None, 21],
#     '性别': ['男', None, '男', '男'],
# }
# 创建随机数组
np.random.seed(100)
arr = {
    'x': [1, 2, 3],
    'y': [4, 5, 6]
}


df = pd.DataFrame(arr)
# 只填充性别列缺失值
print(df)
# Out:
#    x  y
# 0  1  4
# 1  2  5
# 2  3  6
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[84], line 29
#      27 # 只填充性别列缺失值
#      28 print(df)
# ---> 29 df.plot(kind='scatter', x='x', y='y')
#
# File /opt/miniconda3/envs/edu/lib/python3.9/site-packages/pandas/plotting/_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# File /opt/miniconda3/envs/edu/lib/python3.9/site-packages/pandas/plotting/_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File /opt/miniconda3/envs/edu/lib/python3.9/site-packages/pandas/plotting/_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
