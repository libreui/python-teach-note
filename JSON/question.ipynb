# %%
import json

from numpy import dtype
from numpy.matrixlib.defmatrix import matrix
from numpy.testing.print_coercion_tables import print_new_cast_table
from pandas import Series

# 问题1：
# 1. 解析这个books.json
# 2. 把其中数的一些字段整理出来，比如：书名、作者、出版社、出版日期、价格、
# 3. 使用表格库tabulate打印出来
# 4. 保存表格到json文件
json.dump(books, f, ensure_ascii=False, indent=4)

# %%
import numpy as np

arr_a = np.array([[1, 2], [4, 5]])
print(arr_a)
# arr_b = np.reshape(arr_a, (4, 3))
# print(arr_b)
arr_c = np.reshape(arr_a, (6, 3))
print(arr_c)

# %%
import pandas as pd
import numpy as np

# arr = [
#     ['张三', 18, '男'],
#     ['李四', 19, '男'],
#     ['王五', 20, '男'],
#     ['赵六', 21, '男'],
# ]
# df = pd.DataFrame(arr, columns=['姓名', '年龄', '性别'])
# print(df)

# arr = {
#     '姓名': ['张三', '李四', '王五', '赵六'],
#     '年龄': [18, 19, None, 21],
#     '性别': ['男', None, '男', '男'],
# }
# 创建随机数组
np.random.seed(100)
arr = {
    'x': [1, 2, 3],
    'y': [4, 5, 6]
}


df = pd.DataFrame(arr)
# 只填充性别列缺失值
print(df)

# %%
import matplotlib.pyplot as plt

x = [1 ,2 ,3, 4]
y = [_y**2 for _y in x]
x1 = [1 ,2 ,3, 4]
y1 = [_y**3 for _y in x1]

fig, ax = plt.subplots()
# 标题
ax.title.set_text('Square')
# 折线图
# 标签
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.legend(['1_class', '2_class'])
# x轴刻度
ax.set_xticks(x)
ax.set_yticks(y+y1)
# 折线图
plot = ax.plot(x, y, ":ob", x1, y1, ":or")

plt.show()
